# %% [markdown]
# # Problem 1
#
# Fizikte, bir nesnenin sabit ivmeyle hareket ederken son hızını
# (veya hızını) bulmak için aşağıdaki denklem kullanılabilir:
# ```
# vf = vi + at
# burada:
# vf= son hız
# vi= ilk hız
# a= hızlanma
# t= zaman
# ```
# İlk hız, ivme ve zaman verildiğinde, son hızı döndürecek bir fonksiyon yazın.

# %%
# 1.Problemin Çözümünü Buraya Yazınız
def sonHiz(ilkHiz,ivme,zaman):
    sonHiz= ilkHiz+(ivme*zaman)
    return sonHiz
ilkHiz=int(input("ilk hız:"))
ivme=int(input("ivme:"))
zaman=int(input("zaman:"))
print(sonHiz(ilkHiz,ivme,zaman))
# Out:
# 110

# %% [markdown]
# # Problem 2
#
# 1'den 1000'e kadar olan sayılardan mükemmel sayı olanları ekrana yazdırın. Bunun için bir sayının mükemmel olup olmadığını dönen bir tane fonksiyon yazın.
#
# Bir sayının bölenlerinin toplamı kendine eşitse bu sayı mükemmel bir sayıdır. Örnek olarak 6 mükemmel bir sayıdır (1 + 2 + 3 = 6).

# %%
# 2.Problemin Çözümünü Buraya Yazınız
def muk(a):
    
    ml=[]
    for sayi in range(1,a):
        c=0
        for i in range(1,sayi):
            
            if sayi%i==0:
                c+=i
                
        if c==sayi:
            ml.append(sayi)
    print(ml)    
muk(1000)
# Out:
# [6, 28, 496]

# %% [markdown]
# # Problem 3
#
# 1'den 100'e kadar olan sayılardan pisagor üçgeni oluşturanları ekrana yazdıran bir fonksiyon yazın.(a <= 100,b <= 100)

# %%
def pisa():
    plist=dict()
    for a in range(1,101):
        for b in range(1,101):
            c=(a**2+b**2)**(1/2)
            if c%1==0:
                c=int(c)
                plist[c]=[a,b]
    print(plist)
pisa()
# Out:
# {5: [4, 3], 13: [12, 5], 10: [8, 6], 25: [24, 7], 17: [15, 8], 15: [12, 9], 41: [40, 9], 26: [24, 10], 61: [60, 11], 20: [16, 12], 37: [35, 12], 85: [84, 13], 50: [48, 14], 39: [36, 15], 34: [30, 16], 65: [63, 16], 30: [24, 18], 82: [80, 18], 29: [21, 20], 52: [48, 20], 101: [99, 20], 35: [28, 21], 75: [72, 21], 40: [32, 24], 51: [45, 24], 74: [70, 24], 45: [36, 27], 53: [45, 28], 100: [96, 28], 78: [72, 30], 68: [60, 32], 55: [44, 33], 91: [84, 35], 60: [48, 36], 89: [80, 39], 58: [42, 40], 104: [96, 40], 70: [56, 42], 73: [55, 48], 80: [64, 48], 102: [90, 48], 90: [72, 54], 106: [90, 56], 95: [76, 57], 87: [63, 60], 109: [91, 60], 105: [84, 63], 97: [72, 65], 110: [88, 66], 115: [92, 69], 120: [96, 72], 125: [100, 75], 116: [84, 80]}

# %%
# 3.Problemin Çözümünü Buraya Yazınız
def sq():
   c=1
   for a in range(1,101):
        for b in range(1,101):
            
            
            c=(a**2+b**2)**(1/2)
            if c%1==0:
                
                print(a,"-",b,"-",c)
           



sq()
# Out:
# 3 - 4 - 5.0
# 4 - 3 - 5.0
# 5 - 12 - 13.0
# 6 - 8 - 10.0
# 7 - 24 - 25.0
# 8 - 6 - 10.0
# 8 - 15 - 17.0
# 9 - 12 - 15.0
# 9 - 40 - 41.0
# 10 - 24 - 26.0
# 11 - 60 - 61.0
# 12 - 5 - 13.0
# 12 - 9 - 15.0
# 12 - 16 - 20.0
# 12 - 35 - 37.0
# 13 - 84 - 85.0
# 14 - 48 - 50.0
# 15 - 8 - 17.0
# 15 - 20 - 25.0
# 15 - 36 - 39.0
# 16 - 12 - 20.0
# 16 - 30 - 34.0
# 16 - 63 - 65.0
# 18 - 24 - 30.0
# 18 - 80 - 82.0
# 20 - 15 - 25.0
# 20 - 21 - 29.0
# 20 - 48 - 52.0
# 20 - 99 - 101.0
# 21 - 20 - 29.0
# 21 - 28 - 35.0
# 21 - 72 - 75.0
# 24 - 7 - 25.0
# 24 - 10 - 26.0
# 24 - 18 - 30.0
# 24 - 32 - 40.0
# 24 - 45 - 51.0
# 24 - 70 - 74.0
# 25 - 60 - 65.0
# 27 - 36 - 45.0
# 28 - 21 - 35.0
# 28 - 45 - 53.0
# 28 - 96 - 100.0
# 30 - 16 - 34.0
# 30 - 40 - 50.0
# 30 - 72 - 78.0
# 32 - 24 - 40.0
# 32 - 60 - 68.0
# 33 - 44 - 55.0
# 33 - 56 - 65.0
# 35 - 12 - 37.0
# 35 - 84 - 91.0
# 36 - 15 - 39.0
# 36 - 27 - 45.0
# 36 - 48 - 60.0
# 36 - 77 - 85.0
# 39 - 52 - 65.0
# 39 - 80 - 89.0
# 40 - 9 - 41.0
# 40 - 30 - 50.0
# 40 - 42 - 58.0
# 40 - 75 - 85.0
# 40 - 96 - 104.0
# 42 - 40 - 58.0
# 42 - 56 - 70.0
# 44 - 33 - 55.0
# 45 - 24 - 51.0
# 45 - 28 - 53.0
# 45 - 60 - 75.0
# 48 - 14 - 50.0
# 48 - 20 - 52.0
# 48 - 36 - 60.0
# 48 - 55 - 73.0
# 48 - 64 - 80.0
# 48 - 90 - 102.0
# 51 - 68 - 85.0
# 52 - 39 - 65.0
# 54 - 72 - 90.0
# 55 - 48 - 73.0
# 56 - 33 - 65.0
# 56 - 42 - 70.0
# 56 - 90 - 106.0
# 57 - 76 - 95.0
# 60 - 11 - 61.0
# 60 - 25 - 65.0
# 60 - 32 - 68.0
# 60 - 45 - 75.0
# 60 - 63 - 87.0
# 60 - 80 - 100.0
# 60 - 91 - 109.0
# 63 - 16 - 65.0
# 63 - 60 - 87.0
# 63 - 84 - 105.0
# 64 - 48 - 80.0
# 65 - 72 - 97.0
# 66 - 88 - 110.0
# 68 - 51 - 85.0
# 69 - 92 - 115.0
# 70 - 24 - 74.0
# 72 - 21 - 75.0
# 72 - 30 - 78.0
# 72 - 54 - 90.0
# 72 - 65 - 97.0
# 72 - 96 - 120.0
# 75 - 40 - 85.0
# 75 - 100 - 125.0
# 76 - 57 - 95.0
# 77 - 36 - 85.0
# 80 - 18 - 82.0
# 80 - 39 - 89.0
# 80 - 60 - 100.0
# 80 - 84 - 116.0
# 84 - 13 - 85.0
# 84 - 35 - 91.0
# 84 - 63 - 105.0
# 84 - 80 - 116.0
# 88 - 66 - 110.0
# 90 - 48 - 102.0
# 90 - 56 - 106.0
# 91 - 60 - 109.0
# 92 - 69 - 115.0
# 96 - 28 - 100.0
# 96 - 40 - 104.0
# 96 - 72 - 120.0
# 99 - 20 - 101.0
# 100 - 75 - 125.0

# %% [markdown]
# # Problem 4
#
# Bir duvar boyamaya karar verdiniz. Boya kutusunun üzerindeki talimatta, 1 kutu boyanın 5 metrekarelik bir duvarı boyayabileceği yazıyor. Rastgele bir duvar yüksekliği ve genişliği verildiğinde, kaç kutu boya satın almanız gerektiğini hesaplayın.
#
# kutu sayısı = (duvar yüksekliği * duvar genişliği) ÷ kutu başına kaplama.
#
# örneğin Yükseklik = 2, Genişlik = 4, Kaplama = 5
#
# kutu sayısı = (2 * 4) ÷ 5 = 1.6
#
# Ancak bir kutu boyanın 0,6'sını satın alamayacağınız için, sonuç 2 kutuya yuvarlanmalıdır .

# %%
import math

def kutu(h,wide):
    box=(h*wide)/5
    box=math.ceil(box)
    

        

    print((box))
h=int(input("yükseklik:"))
wide=int(input("Genişlik:"))
kutu(h,wide)
# Out:
# 2

# %%
# 4.Problemin Çözümünü Buraya Yazınız


def kutu(h,wide):
    box=(h*wide)/5
    box=1.2
    box2=round(box,0)
    if box>box2:
        box2=box2+1
    

        

    print(int(box2))
h=int(input("yükseklik:"))
wide=int(input("Genişlik:"))
kutu(h,wide)
# Out:
# 2.0

# %% [markdown]
# # Problem 5
#
# Bir kelimedeki ünlü ve ünsüz harfleri sayan bir fonksiyon yazınız.

# %%
# 5.Problemin Çözümünü Buraya Yazınız
unlu=["a","e","i","u","o"]
unsuz=["z","b","c","d","f","g","h","j","k","l","m","n","p","q","r","s","t","v","w","x","y"]
def un (x):
    cUnlu=0
    cUnsuz=0
    for i in x:
        if i in unlu:
            cUnlu+=1
        elif i in unsuz:
            cUnsuz+=1
    print(f"ünlü={cUnlu}, ünsüz={cUnsuz}")

word=(input("kelime:")).lower()
un(word)
# Out:
# ünlü=1, ünsüz=0

# %% [markdown]
# # Problem 6
#
# Verilen bir listeden çift sayıları yazdıran bir fonksiyon yazınız.

# %%
# 6.Problemin Çözümünü Buraya Yazınız
def evenNums(x):
    evens=[]
    for i in x:
        if i%2==0:
            evens.append(i)
    print(evens)
liste=[i for i in range(1,20)]
evenNums(liste)
# Out:
# [2, 4, 6, 8, 10, 12, 14, 16, 18]

# %% [markdown]
# # Problem 7
#
# 0'dan 10'a kadar olan sayıların toplamını hesaplayan özyinelemeli (Recursive Function) bir fonksiyon oluşturan bir fonksiyon yazınız.
#
# Özyinelemeli (Recursive Function) bir işlev, kendini tekrar tekrar çağıran bir işlevdir.

# %%
# 7.Problemin Çözümünü Buraya Yazınız
def rec(num):
    if num>0:
        return num+rec(num-1)
    else:
        return 0
res=rec(10)
print(res)
# Out:
# 55

# %%
if 1:
    print("ads")
# Out:
# ads
